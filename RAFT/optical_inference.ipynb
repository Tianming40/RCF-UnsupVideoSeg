# %%
import os
os.environ['DISPLAY'] = ''

# %%
# !python inference_demo.py --model=/media/mitiadmin/Micron_7450_1/tianming/RCF-UnsupVideoSeg/RAFT/models/raft-things.pth --path=/media/mitiadmin/Micron_7450_1/tianming/dataset/data_medical/JPEGImages/instrument_dataset_1/
# Out:
# /home/tianming/anaconda3/envs/rcf/lib/python3.9/site-packages/torch/functional.py:478: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2894.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Traceback (most recent call last):
#   File "/media/mitiadmin/Micron_7450_1/tianming/RCF-UnsupVideoSeg/RAFT/inference_demo.py", line 293, in <module>
#     demo(args)      # 前向
#   File "/media/mitiadmin/Micron_7450_1/tianming/RCF-UnsupVideoSeg/RAFT/inference_demo.py", line 93, in demo
#     viz(image1, flow_up,count)
#   File "/media/mitiadmin/Micron_7450_1/tianming/RCF-UnsupVideoSeg/RAFT/inference_demo.py", line 34, in viz
#     np.save('/root/autodl-tmp/RCF-UnsupVideoSeg-main/data/data_medical/Flows_NewCT2/instrument_dataset_1/{:04d}.npy'.format(count), flo_16bit)
# ...
